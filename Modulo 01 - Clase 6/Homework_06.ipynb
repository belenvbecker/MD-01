# %% [markdown]
# # Práctica Clase 6

# %% [markdown]
# 1) Cargar el dataset "Emisiones_CO2.csv" provisto en la clase 2 en un Dataframe de Pandas, quitar los registros que contengan valores faltantes e implementar una nueva columna, que contenga el resultado de una función Hash aplicada sobre el campo "Código de País" y se denomine "Clave_Hash".<br>
# Consideraciones: Se puede utilizar la función provista.

# %%
def hash_function(key):
    return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))

# %%
print(hash_function('pato'))
print(hash_function('tapo'))
# Out:
# 1807
# 1799

# %%
import pandas as pd

# %%
df = pd.read_csv('Emisiones_CO2.csv',sep='|',decimal=',', encoding='latin-1')
df
# Out:
#       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 0                ABW           Aruba  América Latina y Caribe  1960       NaN
# 1                ABW           Aruba  América Latina y Caribe  1961       NaN
# 2                ABW           Aruba  América Latina y Caribe  1962       NaN
# 3                ABW           Aruba  América Latina y Caribe  1963       NaN
# 4                ABW           Aruba  América Latina y Caribe  1964       NaN
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
#        CO2 per cápita (toneladas métricas)
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 11122                             0.731867
# 11123                             0.569255
# 11124                             0.600521
# 11125                             0.646073
# 11126                             0.691698
#
# [11127 rows x 6 columns]

# %%
df.dropna(inplace=True)

# %%
df['Clave_Hash']= df['Código de país'].apply(hash_function)
df
# Out:
#       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26               ABW           Aruba  América Latina y Caribe  1986   179,683
# 27               ABW           Aruba  América Latina y Caribe  1987   447,374
# 28               ABW           Aruba  América Latina y Caribe  1988   612,389
# 29               ABW           Aruba  América Latina y Caribe  1989   649,059
# 30               ABW           Aruba  América Latina y Caribe  1990  1.840,83
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
#        CO2 per cápita (toneladas métricas)  Clave_Hash
# 26                                2.868319         910
# 27                                7.234964         910
# 28                               10.026508         910
# 29                               10.634733         910
# 30                               29.620165         910
# ...                                    ...         ...
# 11122                             0.731867         951
# 11123                             0.569255         951
# 11124                             0.600521         951
# 11125                             0.646073         951
# 11126                             0.691698         951
#
# [9029 rows x 7 columns]

# %% [markdown]
# 2. A partir del Dataframe creado en el punto 1, construir uno nuevo, que contenga solo los valores distintos de la tupla "Clave_Hash", "Código de País" , "Nombre de país" y "Región". Quitando luego del dataframe original los campos "Código de País" , "Nombre de país" y "Región"

# %%
df
# Out:
#       Código de país Nombre del país                   Región   Año  CO2 (kt)  \
# 26               ABW           Aruba  América Latina y Caribe  1986   179,683
# 27               ABW           Aruba  América Latina y Caribe  1987   447,374
# 28               ABW           Aruba  América Latina y Caribe  1988   612,389
# 29               ABW           Aruba  América Latina y Caribe  1989   649,059
# 30               ABW           Aruba  América Latina y Caribe  1990  1.840,83
# ...              ...             ...                      ...   ...       ...
# 11122            ZWE        Zimbabue      África subsahariana  2007  9.732,22
# 11123            ZWE        Zimbabue      África subsahariana  2008  7.682,37
# 11124            ZWE        Zimbabue      África subsahariana  2009  8.239,75
# 11125            ZWE        Zimbabue      África subsahariana  2010  9.028,15
# 11126            ZWE        Zimbabue      África subsahariana  2011  9.860,56
#
#        CO2 per cápita (toneladas métricas)  Clave_Hash
# 26                                2.868319         910
# 27                                7.234964         910
# 28                               10.026508         910
# 29                               10.634733         910
# 30                               29.620165         910
# ...                                    ...         ...
# 11122                             0.731867         951
# 11123                             0.569255         951
# 11124                             0.600521         951
# 11125                             0.646073         951
# 11126                             0.691698         951
#
# [9029 rows x 7 columns]

# %%
nuevo_df=df[['Clave_Hash', 'Código de país', 'Nombre del país', 'Región']].drop_duplicates()

# %%
nuevo_df.reset_index()
# Out:
#      index  Clave_Hash Código de país                Nombre del país  \
# 0       26         910            ABW                          Aruba
# 1       87         870            AND                        Andorra
# 2      104         858            AFG                     Afganistán
# 3      156         893            AGO                         Angola
# 4      208         856            ALB                        Albania
# ..     ...         ...            ...                            ...
# 194  10867         927            YEM                          Yemen
# 195  10919         889            ZAF                      Sudáfrica
# 196  10971         877            COD  Congo (República Democrática)
# 197  11027         909            ZMB                         Zambia
# 198  11079         951            ZWE                       Zimbabue
#
#                               Región
# 0            América Latina y Caribe
# 1              Europa y Asia Central
# 2                        Sur de Asia
# 3                África subsahariana
# 4              Europa y Asia Central
# ..                               ...
# 194  Oriente Medio y Norte de África
# 195              África subsahariana
# 196              África subsahariana
# 197              África subsahariana
# 198              África subsahariana
#
# [199 rows x 5 columns]

# %%
df.drop(['Código de país', 'Nombre del país', 'Región'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop(['Código de país', 'Nombre del país', 'Región'], axis=1, inplace=True)
#
# File c:\Users\belen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File c:\Users\belen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File c:\Users\belen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File c:\Users\belen\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['Código de país', 'Nombre del país', 'Región'] not found in axis"

# %%
df.reset_index()
# Out:
#       index   Año  CO2 (kt)  CO2 per cápita (toneladas métricas)  Clave_Hash
# 0        26  1986   179,683                             2.868319         910
# 1        27  1987   447,374                             7.234964         910
# 2        28  1988   612,389                            10.026508         910
# 3        29  1989   649,059                            10.634733         910
# 4        30  1990  1.840,83                            29.620165         910
# ...     ...   ...       ...                                  ...         ...
# 9024  11122  2007  9.732,22                             0.731867         951
# 9025  11123  2008  7.682,37                             0.569255         951
# 9026  11124  2009  8.239,75                             0.600521         951
# 9027  11125  2010  9.028,15                             0.646073         951
# 9028  11126  2011  9.860,56                             0.691698         951
#
# [9029 rows x 5 columns]
